# %%
import yfinance as yf
ticker = yf.Ticker('GOOGL').info
market_price = ticker['open']
previous_close_price = ticker['regularMarketPreviousClose']
print('Ticker: GOOGL')
print('Market Open:', market_price)
print('Previous Close Price:', previous_close_price)
# Out:
# Ticker: GOOGL
# Market Open: 128.66
# Previous Close Price: 129.69

# %%
# Set the start and end date
start_date = '2020-01-01'
end_date = '2023-08-14'
 
# Set the ticker
ticker = 'GOOGL'
 
# Get the data
data = yf.download(ticker, start_date, end_date)
 
# Print the last 5 rows
print(data.tail())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-07  129.160004  131.610001  129.020004  131.529999  131.529999
# 2023-08-08  130.619995  131.509995  129.539993  131.399994  131.399994
# 2023-08-09  131.660004  132.039993  129.000000  129.660004  129.660004
# 2023-08-10  131.320007  132.050003  129.449997  129.690002  129.690002
# 2023-08-11  128.660004  129.929993  128.169998  129.559998  129.559998
#
#               Volume
# Date
# 2023-08-07  22746300
# 2023-08-08  23535200
# 2023-08-09  24912900
# 2023-08-10  20857800
# 2023-08-11  19569200

# %%
import mplfinance as mpf

# %%
start_date = '2020-01-01'
end_date = '2022-01-01'
 
# Add multiple space separated tickers here
ticker = 'NVDA GOOGL BA GSK RACE BUR NG MRK GSPX MSFT ACN NVS LLY PEP BLK AXP'
data = yf.download(ticker, start_date, end_date)
print(data.tail())
# Out:
# [*********************100%%**********************]  15 of 15 completed
#              Adj Close                                                 \
#                    ACN         AXP          BA         BLK        BUR
# Date
# 2021-12-27  405.004852  160.577026  203.169998  884.068054  10.181505
# 2021-12-28  404.946350  160.596558  206.130005  883.349426  10.201104
# 2021-12-29  405.092743  160.030029  203.660004  871.754333   9.897326
# 2021-12-30  403.542175  160.352356  202.710007  875.625671   9.936522
# 2021-12-31  404.244293  159.805344  201.320007  877.350647  10.348094
#
#                                                                       ...  \
#                  GOOGL        GSK         LLY        MRK        MSFT  ...
# Date                                                                  ...
# 2021-12-27  147.906494  41.405064  273.060120  73.184105  337.685150  ...
# 2021-12-28  146.686996  41.423843  271.118164  73.413490  336.501862  ...
# 2021-12-29  146.654999  41.733746  273.069946  73.547295  337.192108  ...
# 2021-12-30  146.200500  41.433231  271.922424  73.728897  334.598633  ...
# 2021-12-31  144.852005  41.414448  270.912262  73.251007  331.640442  ...
#
#               Volume                                                          \
#                GOOGL      GSK      LLY      MRK      MSFT       NG      NVDA
# Date
# 2021-12-27  15976000  2046800  1677100  6334700  19947000   613300  40368600
# 2021-12-28  18200000  2207700  1033900  5727100  15661500   831600  42059100
# 2021-12-29  17788000  2736400  1112300  5926100  15042000   758400  34313900
# 2021-12-30  15688000  2223000  1181500  5859100  15994500  1343800  30886400
# 2021-12-31  18136000  2257500  1315700  6019500  18000800   660300  26653000
#
#
#                 NVS      PEP    RACE
# Date
# 2021-12-27  2222400  2868800  169000
# 2021-12-28  1906700  2332100  142300
# 2021-12-29  1662500  2299500  119400
# 2021-12-30  1268100  1988900  168200
# 2021-12-31  1505400  2914900  133000
#
# [5 rows x 90 columns]

# %%
import matplotlib.pyplot as plt

# %%
import datetime
#Below is the code that will run in python3
# imports and installs
import os
os.system("pip install yfinance")
os.system("pip install mplfinance")
import datetime
import yfinance as yf
import mplfinance as mpf
import matplotlib.pyplot as plt

# %%
yf.download(tickers=stocks, period=period, interval=interval)
# Out:
# [*********************100%%**********************]  6 of 6 completed
#                             Adj Close                                     \
#                                   BLK       BTC-USD     ES=F       GOOGL
# Datetime
# 2023-08-13 23:00:00+00:00         NaN           NaN      NaN         NaN
# 2023-08-13 23:05:00+00:00         NaN           NaN      NaN         NaN
# 2023-08-13 23:10:00+00:00         NaN           NaN      NaN         NaN
# 2023-08-13 23:15:00+00:00         NaN           NaN      NaN         NaN
# 2023-08-13 23:20:00+00:00         NaN           NaN      NaN         NaN
# ...                               ...           ...      ...         ...
# 2023-08-14 14:05:00+00:00  690.770020  29363.236328  4481.75  130.220001
# 2023-08-14 14:10:00+00:00  689.330017  29382.109375  4486.50  130.639999
# 2023-08-14 14:15:00+00:00  689.905029  29371.238281  4486.00  130.429993
# 2023-08-14 14:20:00+00:00  690.390015  29404.564453      NaN  130.380005
# 2023-08-14 14:25:00+00:00         NaN           NaN      NaN  130.619995
#
#                                                        Close                \
#                                 JPY=X        PXE         BLK       BTC-USD
# Datetime
# 2023-08-13 23:00:00+00:00  144.910004        NaN         NaN           NaN
# 2023-08-13 23:05:00+00:00  144.908005        NaN         NaN           NaN
# 2023-08-13 23:10:00+00:00  144.901993        NaN         NaN           NaN
# 2023-08-13 23:15:00+00:00  144.891998        NaN         NaN           NaN
# 2023-08-13 23:20:00+00:00  144.860001        NaN         NaN           NaN
# ...                               ...        ...         ...           ...
# 2023-08-14 14:05:00+00:00  145.473007  32.169998  690.770020  29363.236328
# 2023-08-14 14:10:00+00:00  145.307007  32.229000  689.330017  29382.109375
# 2023-08-14 14:15:00+00:00  145.291000        NaN  689.905029  29371.238281
# 2023-08-14 14:20:00+00:00  145.369003  32.227798  690.390015  29404.564453
# 2023-08-14 14:25:00+00:00  145.343002        NaN         NaN           NaN
#
#                                                 ...     Open              \
#                               ES=F       GOOGL  ...     ES=F       GOOGL
# Datetime                                        ...
# 2023-08-13 23:00:00+00:00      NaN         NaN  ...      NaN         NaN
# 2023-08-13 23:05:00+00:00      NaN         NaN  ...      NaN         NaN
# 2023-08-13 23:10:00+00:00      NaN         NaN  ...      NaN         NaN
# 2023-08-13 23:15:00+00:00      NaN         NaN  ...      NaN         NaN
# 2023-08-13 23:20:00+00:00      NaN         NaN  ...      NaN         NaN
# ...                            ...         ...  ...      ...         ...
# 2023-08-14 14:05:00+00:00  4481.75  130.220001  ...  4479.75  129.990005
# 2023-08-14 14:10:00+00:00  4486.50  130.639999  ...  4482.00  130.220001
# 2023-08-14 14:15:00+00:00  4486.00  130.429993  ...  4486.50  130.660004
# 2023-08-14 14:20:00+00:00      NaN  130.380005  ...      NaN  130.410004
# 2023-08-14 14:25:00+00:00      NaN  130.619995  ...      NaN  130.619995
#
#                                                   Volume                       \
#                                 JPY=X        PXE     BLK     BTC-USD     ES=F
# Datetime
# 2023-08-13 23:00:00+00:00  144.919006        NaN     NaN         NaN      NaN
# 2023-08-13 23:05:00+00:00  144.912003        NaN     NaN         NaN      NaN
# 2023-08-13 23:10:00+00:00  144.910004        NaN     NaN         NaN      NaN
# 2023-08-13 23:15:00+00:00  144.899994        NaN     NaN         NaN      NaN
# 2023-08-13 23:20:00+00:00  144.891006        NaN     NaN         NaN      NaN
# ...                               ...        ...     ...         ...      ...
# 2023-08-14 14:05:00+00:00  145.490997  32.169998  3186.0  28005376.0  23589.0
# 2023-08-14 14:10:00+00:00  145.473007  32.209900  5052.0  27725824.0  25343.0
# 2023-08-14 14:15:00+00:00  145.309006        NaN  3788.0  53123072.0  13226.0
# 2023-08-14 14:20:00+00:00  145.291000  32.200001  3342.0   1523712.0      NaN
# 2023-08-14 14:25:00+00:00  145.343002        NaN     NaN         NaN      NaN
#
#
#                               GOOGL JPY=X     PXE
# Datetime
# 2023-08-13 23:00:00+00:00       NaN     0     NaN
# 2023-08-13 23:05:00+00:00       NaN     0     NaN
# 2023-08-13 23:10:00+00:00       NaN     0     NaN
# 2023-08-13 23:15:00+00:00       NaN     0     NaN
# 2023-08-13 23:20:00+00:00       NaN     0     NaN
# ...                             ...   ...     ...
# 2023-08-14 14:05:00+00:00  256039.0     0     0.0
# 2023-08-14 14:10:00+00:00  331119.0     0  1158.0
# 2023-08-14 14:15:00+00:00  225685.0     0     NaN
# 2023-08-14 14:20:00+00:00  301849.0     0   200.0
# 2023-08-14 14:25:00+00:00       0.0     0     NaN
#
# [186 rows x 36 columns]

# %%
# variables to tune your plots

# valid periods: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
period = '1d'

 # valid intervals: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo
interval = '15m'

# the stocks you want to plot
stocks = ['GOOGL', 'BTC-USD', 'PXE', 'JPY=X', 'ES=F', 'BLK']

#Below is the code that will run in python3
# imports and installs
import os
os.system("pip install yfinance")
os.system("pip install mplfinance")
import datetime
import yfinance as yf
import mplfinance as mpf
import matplotlib.pyplot as plt

# method to grab data and plot the data
def plot_stocks_df(stocks, period='1d' , interval='1m'):
    for stock in stocks:
        plt.figure()
        temp = yf.Ticker(stock)
        hist = yf.download(tickers=stock, period=period, interval=interval)
        print(hist.index)
        mpf.plot(hist, type='candle',
            volume=True, mav=(20,5),title = stock+" "+datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            tight_layout=True, figratio=(10,5))
        globals()[f"plot_{stock}_{interval}"] = plt.gcf()

# call the method
plot_stocks_df(stocks, period, interval)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                '2023-08-14 10:30:00'],
#               dtype='datetime64[ns]', name='Datetime', freq=None)

# %%
# variables to tune your plots

# valid periods: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
from datetime import date


period = '1d'

 # valid intervals: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo
interval = '5m'

# the stocks you want to plot
stocks = ['NVDA', 'GOOGL', 'BA', 'GSK', 'RACE', 'BUR', 'NG', 'MRK', 'GSPX', 'MSFT', 'ACN', 'NVS', 'LLY', 'PEP', 'BLK', 'AXP']



# method to grab data and plot the data
def plot_stocks_df(stocks, period='1d' , interval='5m'):
    for stock in stocks:
        plt.figure()
        temp = yf.Ticker(stock)
        hist = yf.download(tickers=stock, period=period, interval=interval)
        print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        mpf.plot(hist, type='candle',
            volume=True, mav=(20,5),title = stock+" "+datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            tight_layout=True, figratio=(10,5))
        globals()[f"plot_{stock}_{interval}"] = plt.gcf()

# call the method
plot_stocks_df(stocks, period, interval)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:42
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:43
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:43
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:43
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:44
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:44
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:45
# [*********************100%%**********************]  1 of 1 completed
# 2023-08-14 15:26:45
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['GSPX']: Exception('%ticker%: No data found, symbol may be delisted')
# 2023-08-14 15:26:45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10456/847259602.py in <module>
#      28
#      29 # call the method
# ---> 30 plot_stocks_df(stocks, period, interval)
#
# ~\AppData\Local\Temp/ipykernel_10456/847259602.py in plot_stocks_df(stocks, period, interval)
#      22         hist = yf.download(tickers=stock, period=period, interval=interval)
#      23         print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# ---> 24         mpf.plot(hist, type='candle',
#      25             volume=True, mav=(20,5),title = stock+" "+datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
#      26             tight_layout=True, figratio=(10,5))
#
# c:\Users\natal\AppData\Local\Programs\Python\Python39\lib\site-packages\mplfinance\plotting.py in plot(data, **kwargs)
#     415     config['type'] = _get_valid_plot_types(config['type'])
#     416
# --> 417     dates,opens,highs,lows,closes,volumes = _check_and_prepare_data(data, config)
#     418
#     419     config['xlim'] = _check_and_convert_xlim_configuration(data, config)
#
# c:\Users\natal\AppData\Local\Programs\Python\Python39\lib\site-packages\mplfinance\_arg_validators.py in _check_and_prepare_data(data, config)
#      30
#      31     if not isinstance(data.index,pd.core.indexes.datetimes.DatetimeIndex):
# ---> 32         raise TypeError('Expect data.index as DatetimeIndex')
#      33
#      34     # We will not be fully case-insensitive (since Pandas columns as NOT case-insensitive)
#
# TypeError: Expect data.index as DatetimeIndex
